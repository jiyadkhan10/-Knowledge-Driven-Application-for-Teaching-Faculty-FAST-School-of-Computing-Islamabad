# %% [markdown]
# **KRR Semester Project**

# %% [markdown]
# **Convertion of Ontology into RDF Triple Format**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install rdflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.3/500.3 KB 33.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 6.1 MB/s eta 0:00:00
# ...

# %%
import rdflib

# %%
from rdflib import Graph , Namespace

# %%
from rdflib.namespace import RDF, RDFS

# %%
ontology_file = '/content/drive/My Drive/semprojkgld.owl'
g = Graph()
g.parse(ontology_file, format="xml")

# Namespace prefix for the ontology
onto = Namespace("http://example.org/ontology#")

# Iterate through the triples in the graph
for s, p, o in g:
    print(s, p, o) # Print the subject, predicate, and object of each triple

# %% [markdown]
# **Graph Visualization **

# %%
# !pip install owlready2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 71.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for owlready2: filename=Owlready2-0.39-cp38-cp38-linux_x86_64.whl size=22260913 sha256=e8f9dbfd9b106b7b5ece02b9bc48da3c0805f61be63870d19ed80bedab397c5f
#   Stored in directory: /root/.cache/pip/wheels/bd/16/5f/a0bfc34a8f7682cbd6b4d9cb1436c0a0a04ac3579394d7e28a
# Successfully built owlready2
# ...

# %%
from owlready2 import *

# %%
! pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Load the ontology file
onto = get_ontology('/content/drive/My Drive/semprojkgld.owl').load()


# Use the dot() function to visualize the ontology
onto.save(file = "ontology.dot", format = "dot")

# You can then use Graphviz to convert the dot file to an image
# dot -Tpng ontology.dot -o ontology.png

# %%
from graphviz import Source

dot_file = 'ontology.dot'
source = Source.from_file(dot_file)
source.render('ontology', format='png', cleanup=True)
# Out:
# 'ontology.png'
